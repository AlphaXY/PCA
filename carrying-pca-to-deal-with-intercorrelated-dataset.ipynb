# %%
import pandas as pd
import numpy as np

# %%
or_data= pd.read_csv("C:/Users/revecom/Downloads/winequality-red.csv")
or_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
or_data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
or_data.corr()['fixed acidity']['citric acid']
# Out:
# 0.6717034347641041

# %%
 # Import the sklearn function
from sklearn.preprocessing import StandardScaler

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(or_data)
X_scaled
# Out:
# C:\Users\revecom\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\revecom\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# array([[-0.52835961,  0.96187667, -1.39147228, ..., -0.57920652,
#         -0.96024611, -0.78782264],
#        [-0.29854743,  1.96744245, -1.39147228, ...,  0.1289504 ,
#         -0.58477711, -0.78782264],
#        [-0.29854743,  1.29706527, -1.18607043, ..., -0.04808883,
#         -0.58477711, -0.78782264],
#        ...,
#        [-1.1603431 , -0.09955388, -0.72391627, ...,  0.54204194,
#          0.54162988,  0.45084835],
#        [-1.39015528,  0.65462046, -0.77526673, ...,  0.30598963,
#         -0.20930812, -0.78782264],
# ...

# %%
X1 = pd.DataFrame(or_data,columns=or_data.columns)
X1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
# Import the PCA function from sklearn
from sklearn.decomposition import PCA

# Select the number of principal components we will return
num_components = 11

# Create the PCA model
pca = PCA(n_components=num_components)

# Fit the model with the standardised data
pca.fit(X_scaled)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=11, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.26009731, 0.1868235 , 0.14024331, 0.10125174, 0.0811053 ,
#        0.05521602, 0.05152648, 0.04215605, 0.03427563, 0.02732662,
#        0.01501822])

# %%
pca.explained_variance_ratio_.cumsum()
# Out:
# array([0.26009731, 0.44692081, 0.58716412, 0.68841586, 0.76952116,
#        0.82473718, 0.87626366, 0.91841971, 0.95269534, 0.98002195,
#        0.99504017])

# %%
import matplotlib
import matplotlib.pyplot as plt

PC_values = np.arange(pca.n_components_) + 1
plt.plot(PC_values, pca.explained_variance_ratio_, 'ro-', linewidth=2)
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Proportion of Variance Explained')
plt.show()

# %%
pc1 = pca.components_[0]
pc2 = pca.components_[1]
pc3 = pca.components_[2]

# %%
or_data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
pc1
# Out:
# array([ 0.48788336, -0.26512898,  0.47333547,  0.13915442,  0.19742679,
#        -0.04588071,  0.00406675,  0.37030119, -0.43272085,  0.25453535,
#        -0.07317678,  0.11248878])

# %%
pc2
# Out:
# array([-0.00417321,  0.33896786, -0.1373581 ,  0.16773634,  0.18978819,
#         0.25948314,  0.36397137,  0.33078079, -0.06544015, -0.10933362,
#        -0.50270865, -0.47316621])

# %%
# Plot a variable factor map for the first two dimensions.
(fig, ax) = plt.subplots(figsize=(8, 8))
for i in range(0, pca.components_.shape[1]):
    ax.arrow(0,
             0,  # Start the arrow at the origin
             pca.components_[0, i],  #0 for PC1
             pca.components_[1, i],  #1 for PC2
             head_width=0.1,
             head_length=0.1)

    plt.text(pca.components_[0, i] + 0.05,
             pca.components_[1, i] + 0.05,
             or_data.columns.values[i])


an = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(an), np.sin(an))  # Add a unit circle for scale
plt.axis('equal')
ax.set_title('Variable factor map')
plt.show()

# %%
pip install functions
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib
import matplotlib.pyplot as plt

PC_values = np.arange(pca.n_components_) + 1
plt.plot(PC_values, pca.explained_variance_ratio_.cumsum(), 'ro-', linewidth=2)
plt.bar(PC_values, pca.explained_variance_ratio_)
plt.title('Scree Plot')
plt.xlabel('Principal Components')
plt.ylabel('Proportion of Variance Explained')
plt.show()

# %%
import matplotlib.pyplot as plt
x=or_data['fixed acidity']
y=or_data['citric acid']
plt.xlabel('fixed acidity')
plt.ylabel('citric acid')
plt.title('nuage des points x et y')
plt.scatter(x,y,s=2,color='red')

plt.show()

# %%
pd.plotting.scatter_matrix(or_data, c = y, figsize = [8, 8],
s=150, marker = 'D')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000009807BA8>,
# ...
#       dtype=object)
